# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %%time
# 메모리 에러 난다. 수행하지 말자~~
import polars as pl
temp = pl.read_csv('/content/drive/MyDrive/BigData/1brc/measurements.txt',  separator=";",
                    new_columns=["location", "temperature"], has_header=False)
# Out:
# CPU times: user 1min 7s, sys: 23.8 s, total: 1min 31s
# Wall time: 3min 38s

# %%
# %%time
temp.group_by(["location"]).agg(pl.col("temperature").mean())

# %%
# %%time
import polars as pl
temp = pl.scan_csv('/content/drive/MyDrive/BigData/1brc/measurements.txt', separator=";",
with_column_names= lambda cols:["location", "temperature"],has_header=False)
# Out:
# CPU times: user 0 ns, sys: 651 ms, total: 651 ms
# Wall time: 656 ms

# %%
# %%time
print((temp.group_by("location").agg(
[pl.col("temperature").min().alias('min_temp'),
pl.col("temperature").mean().alias('mean_temp'),
pl.col("temperature").max().alias('max_temp')])).collect(streaming=True))
# Out:
# shape: (413, 4)
# ┌──────────────┬──────────┬───────────┬──────────┐
# │ location     ┆ min_temp ┆ mean_temp ┆ max_temp │
# │ ---          ┆ ---      ┆ ---       ┆ ---      │
# │ str          ┆ f64      ┆ f64       ┆ f64      │
# ╞══════════════╪══════════╪═══════════╪══════════╡
# │ Naha         ┆ -25.1    ┆ 23.089602 ┆ 73.5     │
# │ Lisbon       ┆ -30.7    ┆ 17.503542 ┆ 70.7     │
# │ Alexandria   ┆ -29.5    ┆ 20.002092 ┆ 73.7     │
# │ Bulawayo     ┆ -32.3    ┆ 18.904211 ┆ 70.3     │
# │ Seattle      ┆ -38.2    ┆ 11.284138 ┆ 60.7     │
# │ …            ┆ …        ┆ …         ┆ …        │
# │ Saint-Pierre ┆ -41.2    ┆ 5.70646   ┆ 57.4     │
# │ Anchorage    ┆ -50.8    ┆ 2.803966  ┆ 51.4     │
# │ Jerusalem    ┆ -31.7    ┆ 18.29729  ┆ 65.8     │
# │ Sapporo      ┆ -39.2    ┆ 8.902744  ┆ 58.4     │
# │ Stockholm    ┆ -41.9    ┆ 6.606936  ┆ 64.1     │
# └──────────────┴──────────┴───────────┴──────────┘
# CPU times: user 2min 13s, sys: 21.6 s, total: 2min 35s
# Wall time: 28.3 s
