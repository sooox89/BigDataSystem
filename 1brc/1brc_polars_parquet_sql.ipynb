# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import time
stime = time.time()
import polars as pl
temp = pl.read_parquet('/content/drive/MyDrive/BigData/1brc/measurements.parquet')
print(time.time()-stime)
stime = time.time()

ctx = pl.SQLContext(register_globals=True, eager=True)
print(ctx.execute(
    '''SELECT location, min(temperature) as min_temp,
                        avg(temperature) as avg_temp,
                        max(temperature) as max_temp from temp
                        group by location '''))
print(time.time()-stime)
# 384초
# Out:
# 28.276359796524048
# shape: (413, 4)
# ┌────────────────────┬────────────┬───────────┬───────────┐
# │ location           ┆ min_temp   ┆ avg_temp  ┆ max_temp  │
# │ ---                ┆ ---        ┆ ---       ┆ ---       │
# │ str                ┆ f32        ┆ f64       ┆ f32       │
# ╞════════════════════╪════════════╪═══════════╪═══════════╡
# │ Split              ┆ -32.200001 ┆ 16.082975 ┆ 68.5      │
# │ Algiers            ┆ -32.599998 ┆ 18.20987  ┆ 66.199997 │
# │ Memphis            ┆ -30.1      ┆ 17.202887 ┆ 65.5      │
# │ Kuwait City        ┆ -27.0      ┆ 25.698037 ┆ 77.900002 │
# │ Tabriz             ┆ -38.799999 ┆ 12.610882 ┆ 58.799999 │
# │ …                  ┆ …          ┆ …         ┆ …         │
# │ Baguio             ┆ -31.9      ┆ 19.490748 ┆ 74.400002 │
# │ City of San Marino ┆ -40.299999 ┆ 11.806099 ┆ 66.0      │
# │ Parakou            ┆ -22.9      ┆ 26.784075 ┆ 74.800003 │
# │ Marrakesh          ┆ -28.700001 ┆ 19.604865 ┆ 67.0      │
# ...
